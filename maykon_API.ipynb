# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
#api para consultar cotações de diversas moedas, no caso vou focar em Real, Bitcoin e Dólar
import requests

import json

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dic = cotacoes.json()
print(cotacoes_dic)
# Out:
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '4.9393', 'low': '4.9391', 'varBid': '0.0003', 'pctChange': '0.01', 'bid': '4.9387', 'ask': '4.9394', 'timestamp': '1652821196', 'create_date': '2022-05-17 17:59:56'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '4.96', 'low': '4.96', 'varBid': '0', 'pctChange': '0', 'bid': '4.81', 'ask': '5.11', 'timestamp': '1652816340', 'create_date': '2022-05-17 16:39:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '3.8602', 'low': '3.8502', 'varBid': '-0.0039', 'pctChange': '-0.1', 'bid': '3.8496', 'ask': '3.8514', 'timestamp': '1652837892', 'create_date': '2022-05-17 22:38:12'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.2176', 'low': '5.2057', 'varBid': '-0.0028', 'pctChange': '-0.05', 'bid': '5.2054', 'ask': '5.2066', 'timestamp': '1652837896', 'create_date': '2022-05-17 22:38:16'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '6.174', 'low': '6.1622', 'varBid': '-0.0045', 'pctChange': '-0.07', 'bid': '6.1625', 'ask': '6.1654', 'timestamp': '1652837896', 'create_date': '2022-05-17 22:38:16'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.0418', 'low': '0.0418', 'varBid': '0', 'pctChange': '0', 'bid': '0.0418', 'ask': '0.0418', 'timestamp': '1652821196', 'create_date': '2022-05-17 17:59:56'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '156.259', 'low': '147.4', 'varBid': '-1855', 'pctChange': '-1.21', 'bid': '150.894', 'ask': '151.031', 'timestamp': '1652837914', 'create_date': '2022-05-17 22:38:34'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '370', 'low': '349', 'varBid': '10.05', 'pctChange': '2.84', 'bid': '362', 'ask': '363.66', 'timestamp': '1652837879', 'create_date': '2022-05-17 22:37:59'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03825', 'low': '0.03813', 'varBid': '0.0001', 'pctChange': '0.26', 'bid': '0.03824', 'ask': '0.03826', 'timestamp': '1652837897', 'create_date': '2022-05-17 22:38:17'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '4.9771', 'low': '4.9656', 'varBid': '-0.0007', 'pctChange': '-0.01', 'bid': '4.967', 'ask': '4.9707', 'timestamp': '1652837895', 'create_date': '2022-05-17 22:38:15'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.4806', 'low': '3.4632', 'varBid': '-0.0074', 'pctChange': '-0.21', 'bid': '3.4635', 'ask': '3.4645', 'timestamp': '1652837895', 'create_date': '2022-05-17 22:38:15'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.7331', 'low': '0.7323', 'varBid': '-0.0138', 'pctChange': '-1.85', 'bid': '0.7323', 'ask': '0.7324', 'timestamp': '1652837882', 'create_date': '2022-05-17 22:38:02'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.475', 'low': '1.4741', 'varBid': '-0.0191', 'pctChange': '-1.28', 'bid': '1.4748', 'ask': '1.475', 'timestamp': '1652834823', 'create_date': '2022-05-17 21:47:03'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '10.6755', 'low': '10.0486', 'varBid': '-16.6', 'pctChange': '-0.16', 'bid': '10.3037', 'ask': '10.3398', 'timestamp': '1652837897', 'create_date': '2022-05-17 22:38:17'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '2.23', 'low': '2.09', 'varBid': '-0.03', 'pctChange': '-1.22', 'bid': '2.17', 'ask': '2.18', 'timestamp': '1652837912', 'create_date': '2022-05-17 22:38:32'}, 'DOGE': {'code': 'DOGE', 'codein': 'BRL', 'name': 'Dogecoin/Real Brasileiro', 'high': '0.460088', 'low': '0.434212', 'varBid': '-0.007149', 'pctChange': '-1.58', 'bid': '0.44 ...

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin?

# %%
print('Dólar: {}'.format(cotacoes_dic['USD']['bid']))
print('Euro: {}'.format(cotacoes_dic['EUR']['bid']))
print('Bitcoin: {}'.format(cotacoes_dic['BTC']['bid']))
# Out:
# Dólar: 4.9387
# Euro: 5.2054
# Bitcoin: 150.894

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar

# %%
cotacoes_dolar30d = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacoes_dolar_dic = cotacoes_dolar30d.json()
#print(cotacoes_dolar_dic[2]['bid'])
lista_cotacoes_dolar = [float(item['bid']) for item in cotacoes_dolar_dic]
print(lista_cotacoes_dolar)
# Out:
# [4.9387, 5.0606, 5.0588, 5.1342, 5.14, 5.1333, 5.1611, 5.0776, 5.0791, 5.0804, 5.0435, 4.9198, 4.9614, 5.0849, 4.9733, 4.9397, 4.9674, 4.999, 4.8774, 4.795, 4.622, 4.6224, 4.6658, 4.6528, 4.6965, 4.6965, 4.7013, 4.6904, 4.6755, 4.6936]

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/22 a Mai/22

# %%
cotacoes_btc = requests.get('https://economia.awesomeapi.com.br/json/daily/BTC-BRL/200?start_date=20220101&end_date=20220501')
cotacoes_btc_dic = cotacoes_btc.json()
lista_cotacoes_btc = [float(item['bid']) for item in cotacoes_btc_dic]
lista_cotacoes_btc.reverse()
print(lista_cotacoes_btc)
print(len(lista_cotacoes_btc))
# Out:
# [268.0, 267.34, 264.911, 262.001, 251.225, 247.533, 236.0, 238.019, 238.359, 238.083, 240.006, 245.346, 237.947, 239.745, 240.639, 240.612, 234.757, 237.353, 229.413, 222.75, 200.302, 193.277, 200.292, 203.675, 203.535, 202.814, 201.953, 204.283, 206.375, 206.2, 205.145, 205.55, 196.413, 197.522, 220.998, 222.538, 225.905, 232.964, 234.123, 233.535, 230.011, 223.5, 222.865, 222.687, 223.3, 231.147, 226.616, 211.66, 207.542, 207.589, 200.198, 190.157, 195.9, 188.583, 197.358, 203.789, 202.702, 196.451, 222.192, 227.91, 225.113, 215.0, 200.011, 201.634, 195.812, 195.025, 196.779, 210.997, 199.023, 197.25, 198.0, 193.245, 202.462, 201.728, 208.684, 206.721, 210.778, 212.688, 207.898, 204.01, 209.119, 208.49, 212.709, 212.0, 212.453, 222.999, 225.509, 227.61, 226.167, 218.0, 217.842, 215.9, 218.0, 215.993, 213.025, 205.401, 208.521, 200.711, 202.882, 200.638, 187.27, 189.366, 194.343, 188.884, 191.721, 191.719, 188.05, 190.949, 194.746, 192.54, 188.792, 191.62, 190.509, 190.606, 197.622, 191.12, 195.346, 197.312, 192.795, 188.645, 192.293]
# 121

# %% [markdown]
# #### Gráfico com as cotações do BitCoin

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(lista_cotacoes_btc)
plt.show()
